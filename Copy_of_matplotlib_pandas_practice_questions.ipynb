# %% [markdown]
# <a href="https://colab.research.google.com/github/ugadityaa45/1stdayaccio/blob/main/Copy_of_matplotlib_pandas_practice_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib + Pandas Practice Notebook
#
#
# ## What you will practice
# 1. Creating a Python list and plotting simple charts (Line, Bar, Pie) with Matplotlib.
# 2. Creating a Pandas Series and plotting a Line chart.
# 3. Creating a Pandas DataFrame and plotting a Line chart between two columns.
# 4. Doing a GroupBy in Pandas and plotting a Bar chart.
#
# Note: Keep the code simple. Avoid unnecessary options or styling.

# %% [markdown]
# ## Q0. Import Libraries
# Import only what is needed to solve the problems later in this notebook.
# - Import `matplotlib.pyplot` as `plt`
# - Import `pandas` as `pd`

# %%
# answer here

# %% [markdown]
# ## Q0. Import Libraries
# Import only what is needed to solve the problems later in this notebook.
# - Import `matplotlib.pyplot` as `plt`
# - Import `pandas` as `pd`

# %% [markdown]
# ## Q0. Import Libraries
# Import only what is needed to solve the problems later in this notebook.
# - Import `matplotlib.pyplot` as `plt`
# - Import `pandas` as `pd`

# %% [markdown]
# ## Q0. Import Libraries
# Import only what is needed to solve the problems later in this notebook.
# - Import `matplotlib.pyplot` as `plt`
# - Import `pandas` as `pd`

# %% [markdown]
# ## Q1. Create a List
# Create a Python list named `numbers` with **five** numeric values of your choice. Then print the list.
# - Name the variable exactly `numbers`.
# - Use integers only.

# %%
# answer here
numbers = [10, 20, 30, 40, 50]

print(numbers)

# %% [markdown]
# ## Q2. Line Chart from List
# Using the `numbers` list from Q1, plot a **line chart**.
# - Use `plt.plot(numbers)`
# - Add a title "Simple Line Chart"
# - Label x-axis as `Index` and y-axis as `Value`
# - Show the plot

# %%
# answer here
import matplotlib.pyplot as plt
numbers = [10, 20, 30, 40, 50]
plt.plot(numbers)
plt.title("Simple Line Chart")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Q3. Bar Chart from List
# Plot a **bar chart** using the same `numbers` list.
# - X-axis should be the index positions of the list (0 to length-1)
# - Add a title "Simple Bar Chart"
# - Label axes appropriately
# - Show the plot

# %%
# answer here
numbers = [10, 20, 30, 40, 50]
plt.bar(range(len(numbers)), numbers)
plt.title("Simple Bar Chart")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Q4. Pie Chart from List
# Plot a **pie chart** using the `numbers` list.
# - Provide labels for each slice (e.g., A, B, C, D, E)
# - Show percentage on slices using `autopct="%1.1f%%"`
# - Add a title "Simple Pie Chart"
# - Show the plot

# %%
# answer here
import matplotlib.pyplot as plt

numbers = [10, 20, 30, 40, 50]
labels = ['A', 'B', 'C', 'D', 'E']

plt.pie(numbers, labels=labels, autopct="%1.1f%%")
plt.title("Simple Pie Chart")
plt.show()

# %% [markdown]
# ## Q5. Create a Pandas Series
# Create a Pandas **Series** named `sales` with five values (e.g., monthly sales). Use month names as the index: `Jan`, `Feb`, `Mar`, `Apr`, `May`.
# - Print the Series

# %%
# answer here
import pandas as pd

sales = pd.Series([2500, 3000, 2800, 3500, 4000],index=['Jan', 'Feb', 'Mar', 'Apr', 'May'])

print(sales)
# Out:
# Jan    2500
# Feb    3000
# Mar    2800
# Apr    3500
# May    4000
# dtype: int64

# %% [markdown]
# ## Q6. Line Chart from Series
# Plot a **line chart** from the `sales` Series.
# - Use `sales.plot(kind="line", title="Monthly Sales")`
# - Label x-axis as `Month` and y-axis as `Sales`
# - Show the plot

# %%
# answer here
import matplotlib.pyplot as plt
import pandas as pd

sales = pd.Series([2500, 3000, 2800, 3500, 4000],
                  index=['Jan', 'Feb', 'Mar', 'Apr', 'May'])

sales.plot(kind="line", title="Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ## Q7. Create a DataFrame
# Create a **DataFrame** named `df` with three columns: `Month`, `Sales`, `Profit`.
# - `Month`: `Jan`, `Feb`, `Mar`, `Apr`, `May`
# - `Sales`: choose five integers
# - `Profit`: choose five integers
# - Print the DataFrame

# %%
# answer here
import pandas as pd

data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'Sales': [2500, 3000, 2800, 3500, 4000],
    'Profit': [500, 700, 650, 800, 900]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Month  Sales  Profit
# 0   Jan   2500     500
# 1   Feb   3000     700
# 2   Mar   2800     650
# 3   Apr   3500     800
# 4   May   4000     900

# %% [markdown]
# ## Q8. Line Chart Between Two Columns
# Using `df`, plot **two line charts on the same axes**: one for `Sales` and one for `Profit` against `Month`.
# - Use `plt.plot(df["Month"], df["Sales"], label="Sales")`
# - Use `plt.plot(df["Month"], df["Profit"], label="Profit")`
# - Add title "Sales vs Profit"
# - Label axes and add legend
# - Show the plot

# %%
# answer here
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'Sales': [2500, 3000, 2800, 3500, 4000],
    'Profit': [500, 700, 650, 800, 900]
}

df = pd.DataFrame(data)

plt.plot(df["Month"], df["Sales"], label="Sales")
plt.plot(df["Month"], df["Profit"], label="Profit")
plt.title("Sales vs Profit")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %% [markdown]
# ## Q9. GroupBy Setup
# Create a new DataFrame named `df_group` with two columns: `Category` and `Sales`.
# - Include at least 7 rows
# - Use categories like `A`, `B`, `C` (repeated)
# - Use integers for `Sales`
# - Print the DataFrame

# %%
# answer here
import pandas as pd

df_group = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'C', 'B', 'C', 'A'],
    'Sales': [200, 300, 250, 400, 350, 500, 150]
})

print(df_group)
# Out:
#   Category  Sales
# 0        A    200
# 1        B    300
# 2        A    250
# 3        C    400
# 4        B    350
# 5        C    500
# 6        A    150

# %% [markdown]
# ## Q10. GroupBy and Bar Chart
# Group `df_group` by `Category` and sum the `Sales`. Store the result in a variable named `grouped`.
# - Print `grouped`
# - Plot a **bar chart** from `grouped` with title "Total Sales by Category"
# - Label axes and show the plot

# %%
# answer here
import matplotlib.pyplot as plt
import pandas as pd

df_group = pd.DataFrame({
    'Category': ['A', 'B', 'A', 'C', 'B', 'C', 'A'],
    'Sales': [200, 300, 250, 400, 350, 500, 150]
})

grouped = df_group.groupby('Category')['Sales'].sum()
print(grouped)

grouped.plot(kind='bar', title='Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()
# Out:
# Category
# A    600
# B    650
# C    900
# Name: Sales, dtype: int64
